# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# ---------- HEADER ----------
header = widgets.HTML(
    "<h1 style='color:#b8579d; font-family:sans-serif;'>Mbɔ́ŋ Nhanga Braids</h1>"
)
subtitle = widgets.HTML(
    "<h3 style='color:#555;'>✨ Braiding with culture & care – Asheville, NC ✨</h3>"
)

# ---------- LOCATION INFO ----------
location_info = widgets.HTML(
    "<p><b>📍 Location:</b> Asheville, NC<br>"
    "<b>🏠 In-house Appointments:</b> Available<br>"
    "<b>💁🏾‍♀️ Braids with Hair Included:</b> Yes</p>"
)

# ---------- STYLE CATALOG ----------
style_cards = widgets.HTML(
    """
    <h3 style='color:#9b2c7a;'>Popular Styles & Pricing</h3>
    <ul>
      <li><b>Knotless Braids</b> – $90 (medium), $100 (long)</li>
      <li><b>Box Braids</b> – $90+</li>
      <li><b>Crotchet Braids</b> – $60+</li>
      <li><b>Corn Rows</b> – $30+</li>
      <li><b>Scalp Treatment</b> – $30</li>
      <li><b>Loc Retwist</b> – $50+</li>
      <li><b>Hair Dye</b> – $20+</li>
      <li><b>Henna</b> – $40+</li>
    </ul>
    <p style='font-size: 13px;'>*Final pricing may vary based on hair length and service add-ons.</p>
    """
)

# ---------- IMAGE GALLERY ----------
gallery = widgets.HTML(
    """
    <h3 style='color:#9b2c7a;'>Gallery</h3>
    <img src='https://github.com/akundol/Braids-/blob/main/Screenshot_20250420_135603_Instagram.jpg' width='200' style='margin-right:10px;'/>
    <img src='https://github.com/akundol/Braids-/blob/main/Screenshot_20250420_135652_Instagram.jpg' width='200' style='margin-right:10px;'/>
    <img src='https://github.com/akundol/Braids-/blob/main/Screenshot_20250420_140605_Instagram.jpg' width='200'/>
    <img src='https://github.com/akundol/Braids-/blob/main/Screenshot_20250420_140938_Instagram.jpg' width='200'/>
    <img src='https://github.com/akundol/Braids-/blob/main/Screenshot_20250420_141340_Instagram.jpg' width='200'/>
    <img src='https://github.com/akundol/Braids-/blob/main/Screenshot_20250420_142534_InCollage%20-%20Collage%20Maker.jpg' width='200'/>
    <img src='https://i.imgur.com/CS1Vvd5.jpg' width='200'/>
    <img src='https://i.imgur.com/CS1Vvd5.jpg' width='200'/>
    <img src='https://i.imgur.com/CS1Vvd5.jpg' width='200'/>






    <p style='font-size: 12px;'>Swipe for more on our Instagram @mbong_nhanga_braids</p>
    """
)

# ---------- APPOINTMENT FORM ----------
name = widgets.Text(placeholder='Your full name')
style = widgets.Dropdown(
    options=[
        'Knotless Braids', 'Box Braids', 'Crotchet Braids', 'Sew-IN Wig', 
        'Corn Rows', 'Hair Wash', 'Crotchet Hair', 'Scalp Treatment', 
        'Loc Retwist', 'Hair Dye', 'Henna'
    ],
    description='Style:',
    style={'description_width': 'initial'}
)

length = widgets.Dropdown(
    options=['Short', 'Medium', 'Long', 'Extra Long'],
    description='Length:',
    style={'description_width': 'initial'}
)

date = widgets.DatePicker(description='Date:', style={'description_width': 'initial'})
time = widgets.Dropdown(
    options=['9:00 AM', '11:00 AM', '1:00 PM', '3:00 PM', '5:00 PM'],
    description='Time:',
    style={'description_width': 'initial'}
)

contact = widgets.Text(placeholder='Phone or email')
in_house = widgets.Checkbox(value=False, description='I need in-house service')

submit_button = widgets.Button(description='Book Appointment', button_style='success')
output = widgets.Output()

def on_submit_clicked(b):
    with output:
        clear_output()
        print("🎉 Booking Confirmed!\n")
        print(f"Name: {name.value}")
        print(f"Style: {style.value} ({length.value})")
        print(f"Date: {date.value.strftime('%A, %B %d, %Y')}")
        print(f"Time: {time.value}")
        print(f"Contact: {contact.value}")
        print(f"In-house: {'Yes' if in_house.value else 'No'}")
        print("\nWe’ll reach out shortly to confirm your appointment. Thank you!")

submit_button.on_click(on_submit_clicked)

form = widgets.VBox([
    widgets.HTML("<h3 style='color:#9b2c7a;'>📆 Book Your Appointment</h3>"),
    name, style, length, date, time, contact, in_house,
    submit_button, output
])

# ---------- FINAL LAYOUT ----------
page = widgets.VBox([
    header, subtitle, location_info, gallery, style_cards, form
])

display(page)

# %%
name = widgets.Text(placeholder='Your full name')
style = widgets.Dropdown(
    options=['Knotless Braids', 'Box Braids', 'Crotchet Braids', 'Sew-IN Wig', 'Corn Rows', 'Hair Wash', 'Crotchet Hair', 'Scalp Treatment', 'Loc Retwist'],
    description='Style:',
    style={'description_width': 'initial'}
)

length = widgets.Dropdown(
    options=['Short', 'Medium', 'Long', 'Extra Long'],
    description='Length:',
    style={'description_width': 'initial'}
)

date = widgets.DatePicker(
    description='Appointment Date:',
    disabled=False,
    style={'description_width': 'initial'}
)

time = widgets.Dropdown(
    options=['9:00 AM', '11:00 AM', '1:00 PM', '3:00 PM', '5:00 PM'],
    description='Time:',
    style={'description_width': 'initial'}
)

contact = widgets.Text(placeholder='Phone or email')

submit_button = widgets.Button(
    description='Book Appointment',
    button_style='success'
)

output = widgets.Output()

# Action on submit
def on_submit_clicked(b):
    with output:
        clear_output()
        print("🎉 Booking Confirmed!\n")
        print(f"Name: {name.value}")
        print(f"Style: {style.value} ({length.value})")
        print(f"Date: {date.value.strftime('%A, %B %d, %Y')}")
        print(f"Time: {time.value}")
        print(f"Contact: {contact.value}")
        print("\nThank you! We’ll reach out to confirm shortly.")

submit_button.on_click(on_submit_clicked)

# Layout
form = widgets.VBox([
    widgets.HTML("<h2 style='color:purple;'>Mbɔ́ŋ Nhanga Braids Appointment Form</h2>"),
    name, style, length, date, time, contact, submit_button, output
])

display(form)
